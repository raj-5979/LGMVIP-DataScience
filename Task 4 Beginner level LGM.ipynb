# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\91842\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\91842\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %%
# Reading the original image
image = cv2.imread('cat.jpg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=186x271 at 0x23874292D90>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=186x271 at 0x23875A457C0>

# %%
inv_gray_image = 255 - gray_image

# %%
inv_gray_image
# Out:
# array([[235, 235, 235, ..., 227, 227, 227],
#        [235, 235, 235, ..., 227, 227, 227],
#        [235, 235, 235, ..., 227, 227, 227],
#        ...,
#        [222, 229, 235, ..., 229, 230, 230],
#        [222, 228, 235, ..., 229, 229, 229],
#        [221, 228, 234, ..., 229, 229, 229]], dtype=uint8)

# %%
display(Image.fromarray(inv_gray_image))
# Out:
# <PIL.Image.Image image mode=L size=186x271 at 0x23877DC8B80>

# %%
blur_image = cv2.GaussianBlur(inv_gray_image, (35, 35), 0)

# %%
display(Image.fromarray(blur_image))
# Out:
# <PIL.Image.Image image mode=L size=186x271 at 0x23877DC8D90>

# %%
inverted_blurred = 255 - blur_image

# %%
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)

# %%
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=186x271 at 0x23877DC8BE0>
